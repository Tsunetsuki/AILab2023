# %%
# CNN
import torch.nn.functional as F
import torch
import torch.nn as nn
import torch.optim as optim
from torch.optim import lr_scheduler
import torch.backends.cudnn as cudnn

# others
import numpy as np
import matplotlib.pyplot as plt
import time
import os
from PIL import Image
from tempfile import TemporaryDirectory
import time

# dataset
import torchvision
from torchvision import datasets, models, transforms
from torchvision.datasets import Flowers102

# read file 
import pandas as pd

# label
from scipy.io import loadmat
import json

# %% [markdown]
# # Use TweetEval emotion recognition dataset

# %%
root = '../../Data/tweeteval/datasets/emotion/'
mapping_file = os.path.join(root, 'mapping.txt')
test_labels_file = os.path.join(root, 'test_labels.txt')
test_text_file = os.path.join(root, 'test_text.txt')
train_labels_file = os.path.join(root, 'train_labels.txt')
train_text_file = os.path.join(root, 'train_text.txt')
val_labels_file = os.path.join(root, 'val_labels.txt')
val_text_file = os.path.join(root, 'val_text.txt')

# %%
mapping_pd = pd.read_csv(mapping_file, sep='\t', header=None)
test_label_pd = pd.read_csv(test_labels_file, sep='\t', header=None)
test_dataset = open(test_text_file).read().split('\n')[:-1] # remove last empty line 
train_label_pd = pd.read_csv(train_labels_file, sep='\t', header=None)
train_dataset = open(train_text_file).read().split('\n')[:-1] # remove last empty line
val_label_pd = pd.read_csv(val_labels_file, sep='\t', header=None)
val_dataset = open(val_text_file).read().split('\n')[:-1] # remove last empty line

# %%
print(f'len(train_dataset)= {len(train_dataset)}')
print(f'len(train_label_pd)= {len(train_label_pd)}')
print(f'=== train_label_pd === \n{train_label_pd.value_counts()}')

print(f'len(train_dataset)= {len(test_dataset)}')
print(f'len(train_label_pd)= {len(test_label_pd)}')
print(f'=== train_label_pd === \n{test_label_pd.value_counts()}')
# Out:
# len(train_dataset)= 3257
# len(train_label_pd)= 3257
# === train_label_pd ===
# 0    1400
# 3     855
# 1     708
# 2     294
# Name: count, dtype: int64
# len(train_dataset)= 1421
# len(train_label_pd)= 1421
# === train_label_pd ===
# 0    558
# 3    382
# 1    358
# 2    123
# Name: count, dtype: int64

# %% [markdown]
# # Task 2
# - Use spaCy to split the tweets into words.
#
# Before start using spaCy
# ```
# conda install -c conda-forge spacy
# python -m spacy download en_core_web_sm
# ```

# %%
import spacy 
from collections import Counter

# use spacy to tokenize the sentence with english model 
nlp = spacy.load("en_core_web_sm")

# join all the sentence together 
text = ' '.join(train_dataset)

# use spacy to tokenize the sentence 
doc = nlp(text)

# filter out the punctuation and stop words
word_freq = Counter(token.text for token in doc \
                    if not token.is_punct and \
                        not token.is_stop and \
                            not token.is_space )
word_freq
# Out:
# Counter({'@user': 2019,
#          'like': 212,
#          'amp': 148,
#          'people': 126,
#          'know': 96,
#          'think': 92,
#          'sad': 90,
#          'got': 85,
#          'day': 81,
#          'u': 80,
#          'time': 78,
#          '✨': 75,
#          '😂': 75,
#          'want': 74,
#          'life': 73,
#          'going': 69,
#          'feel': 67,
#          'angry': 66,
#          '2': 65,
#          'depression': 65,
#          'fear': 64,
#          'love': 64,
#          'good': 63,
#          'today': 61,
#          'work': 59,
#          'fucking': 57,
#          'sadness': 56,
#          'lost': 56,
#          'm': 55,
#          'need': 55,
#          'new': 53,
#          'way': 52,
#          'man': 52,
#          'anger': 52,
#          'awful': 52,
#          'terrorism': 52,
#          'anxiety': 51,
#          'right': 49,
#          'let': 48,
#          'horrible': 47,
#          'rage': 47,
#          'fuming': 46,
#          'shocking': 44,
#          'nightmare': 44,
#          'terrible': 43,
#          'little': 43,
#          'bad': 42,
#          'blues': 41,
#          'fuck': 41,
#          'bully': 40,
#          'hilarious': 40,
#          'night': 40,
#          'depressing': 39,
#          'terror': 39,
#          'amazing': 39,
#          'lol': 39,
#          'find': 38,
#          'happy': 38,
#          'tell': 37,
#          'shit': 37,
#          'better': 37,
#          'look': 37,
#          'makes': 37,
#          'outrage': 37,
#          'things': 37,
#          'stop': 36,
#          'start': 36,
#          'horror': 36,
#          'said': 36,
#          'nt': 36,
#          'getting': 34,
#          'game': 33,
#          'away': 33,
#          'afraid': 33,
#          'watch': 32,
#          'old': 32,
#          'worst': 32,
#          'bitter': 31,
#          'hate': 31,
#          'years': 31,
#          'Trump': 31,
#          '3': 31,
#          '😭': 31,
#          'face': 31,
#          '🙄': 30,
#          'trying': 30,
#          'worry': 29,
#          'thing': 29,
#          'revenge': 29,
#          'smile': 29,
#          'offended': 29,
#          'having': 29,
#          'Watch': 29,
#          'hard': 29,
#          'year': 29,
#          'best': 28,
#          'home': 28,
#          'play': 28,
#          '1': 28,
#          '😡': 28,
#          'broadcast': 28,
#          'thought': 27,
#          'snap': 27,
#          'week': 27,
#          'great': 27,
#          'black': 27,
#          'tonight': 27,
#          'live.ly': 27,
#          'musically': 27,
#          'looking': 27,
#          'wanna': 27,
#          'guys': 26,
#          'tomorrow': 26,
#          'furious': 26,
#          'nervous': 26,
#          'heart': 26,
#          'world': 25,
#          'panic': 25,
#          'person': 25,
#          'hell': 25,
#          'fury': 25,
#          'GBBO': 25,
#          'unhappy': 25,
#          'raging': 25,
#          '️': 25,
#          'hope': 24,
#          'guy': 24,
#          'big': 24,
#          'music': 24,
#          'phone': 24,
#          'wait': 24,
#          'girl': 24,
#          'long': 23,
#          'sadly': 23,
#          'lively': 23,
#          'war': 23,
#          'help': 23,
#          'Pakistan': 23,
#          'live': 23,
#          'service': 23,
#          'ur': 22,
#          'glee': 22,
#          'bit': 22,
#          'watching': 22,
#          'seen': 22,
#          'burning': 22,
#          'sorry': 22,
#          'making': 22,
#          'half': 22,
#          'sober': 22,
#          'na': 21,
#          'shake': 21,
#          'pout': 21,
#          'house': 21,
#          'n': 21,
#          'dark': 21,
#          '❤': 21,
#          'family': 21,
#          'literally': 21,
#          'insult': 21,
#          'news': 21,
#          'grim': 21,
#          'shy': 20,
#          'pretty': 20,
#          'talking': 20,
#          'come': 20,
#          'optimism': 20,
#          'irritate': 20,
#          'gone': 20,
#          'maybe': 20,
#          '😍': 20,
#          'leave': 20,
#          'bc': 20,
#          'real': 20,
#          'days': 20,
#          '4': 20,
#          'stayed': 19,
#          'despair': 19,
#          'gon': 19,
#          'oh': 19,
#          'mourn': 19,
#          'wo': 19,
#          'wish': 19,
#          'talk': 19,
#          'times': 19,
#          'mind': 19,
#          '+': 19,
#          'team': 19,
#          'job': 19,
#          'end': 19,
#          'morning': 19,
#          'police': 19,
#          'ass': 19,
#          'boiling': 19,
#          'die': 19,
#          'playing': 19,
#          'dreadful': 18,
#          'started': 18,
#          'remember': 18,
#          '5': 18,
#          'shaking': 18,
#          'actually': 18,
#          'feeling': 18,
#          'thanks': 18,
#          'alarm': 18,
#          'left': 18,
#          'sleep': 18,
#          'took': 18,
#          'customer': 18,
#          'wrath': 18,
#          'fire': 17,
#          'outside': 17,
#          'Love': 17,
#          'believe': 17,
#          'seriously': 17,
#          'late': 17,
#          'God': 17,
#          '😩': 17,
#          'awe': 17,
#          'says': 17,
#          'country': 17,
#          'cry': 17,
#          'miss': 17,
#          '💖': 17,
#          'wrong': 16,
#          'month': 16,
#          'school': 16,
#          'gloomy': 16,
#          'sting': 16,
#          'comes': 16,
#          'friends': 16,
#          'minutes': 16,
#          'worse': 16,
#          'weary': 16,
#          '20': 16,
#          'quote': 16,
#          'lose': 16,
#          'looks': 16,
#          'taking': 16,
#          'tired': 16,
#          'care': 16,
#          'Oh': 16,
#          'called': 16,
#          'words': 16,
#          'joke': 15,
#          'break': 15,
#          'kind': 15,
#          'birthday': 15,
#          'wow': 15,
#          'horrific': 15,
#          '15': 15,
#          'try': 15,
#          'moment': 15,
#          'sure': 15,
#          'turn': 15,
#          'attack': 15,
#          '10': 15,
#          'crying': 15,
#          'animated': 15,
#          'free': 15,
#          'asked': 15,
#          'takes': 15,
#          'boy': 15,
#          'truth': 15,
#          'racism': 15,
#          'friend': 15,
#          'use': 15,
#          'discourage': 15,
#          'offense': 15,
#          'problem': 14,
#          'heard': 14,
#          'breezy': 14,
#          'hold': 14,
#          'India': 14,
#          'change': 14,
#          'dull': 14,
#          'People': 14,
#          'laughter': 14,
#          'saying': 14,
#          'hilarity': 14,
#          'discouraged': 14,
#          'dream': 14,
#          'funny': 14,
#          'died': 14,
#          'point': 14,
#          'burst': 14,
#          'mean': 14,
#          'future': 14,
#          'found': 14,
#          'watched': 14,
#          'season': 14,
#          'white': 14,
#          'haunt': 14,
#          'sunk': 14,
#          'men': 14,
#          'needs': 14,
#          '😤': 14,
#          'threaten': 13,
#          'lot': 13,
#          'stuff': 13,
#          'fiery': 13,
#          'cheer': 13,
#          'woman': 13,
#          'playful': 13,
#          'sink': 13,
#          'weeks': 13,
#          'Twitter': 13,
#          'happened': 13,
#          'test': 13,
#          'joyful': 13,
#          'run': 13,
#          'shot': 13,
#          's': 13,
#          'head': 13,
#          'told': 13,
#          'Hillary': 13,
#          'mad': 13,
#          'fact': 13,
#          '😳': 13,
#          'wants': 13,
#          'win': 13,
#          'relentless': 13,
#          'word': 13,
#          'state': 13,
#          'money': 13,
#          'class': 13,
#          '7': 13,
#          'issues': 13,
#          '$': 13,
#          'pay': 13,
#          'grudge': 13,
#          'gets': 13,
#          'sparkling': 13,
#          'ask': 13,
#          'w': 13,
#          'kid': 13,
#          'offend': 13,
#          'tears': 13,
#          'cause': 13,
#          'okay': 12,
#          'probably': 12,
#          'hit': 12,
#          'excited': 12,
#          'sick': 12,
#          'singing': 12,
#          'terrorist': 12,
#          'delight': 12,
#          'tweet': 12,
#          'past': 12,
#          'bored': 12,
#          'thank': 12,
#          'car': 12,
#          'saw': 12,
#          'working': 12,
#          'played': 12,
#          'twitter': 12,
#          'absolutely': 12,
#          'kinda': 12,
#          'supposed': 12,
#          'cheering': 12,
#          'fun': 12,
#          'hair': 12,
#          'kill': 12,
#          'ta': 12,
#          'seeing': 12,
#          'scared': 12,
#          '😠': 12,
#          'lies': 12,
#          '🙈': 12,
#          'horrid': 12,
#          'level': 12,
#          'yeah': 12,
#          'hour': 12,
#          'hear': 12,
#          'lmao': 12,
#          'happen': 12,
#          'pine': 12,
#          'media': 12,
#          'players': 12,
#          'true': 12,
#          'weak': 11,
#          'pessimist': 11,
#          'high': 11,
#          'resent': 11,
#          'straight': 11,
#          'concern': 11,
#          'Happy': 11,
#          'King': 11,
#          'Thanks': 11,
#          'Thank': 11,
#          'scare': 11,
#          'rest': 11,
#          'felt': 11,
#          'human': 11,
#          'teams': 11,
#          'buy': 11,
#          'listen': 11,
#          'god': 11,
#          'instead': 11,
#          'broken': 11,
#          'racist': 11,
#          'follow': 11,
#          '🙃': 11,
#          'guess': 11,
#          'madden': 11,
#          'history': 11,
#          'attacks': 11,
#          'room': 11,
#          'killed': 11,
#          'rabid': 11,
#          'feels': 11,
#          'understand': 11,
#          'Today': 11,
#          'stupid': 11,
#          'hands': 11,
#          'exhilarating': 11,
#          'lives': 11,
#          'close': 11,
#          '=': 11,
#          'depress': 11,
#          'dread': 11,
#          'evening': 11,
#          'Like': 11,
#          'afternoon': 11,
#          'gleeful': 11,
#          'restless': 11,
#          'idea': 11,
#          'ai': 11,
#          'body': 11,
#          'video': 11,
#          'means': 11,
#          '😊': 11,
#          'ok': 11,
#          'growl': 10,
#          'fighting': 10,
#          'd': 10,
#          'posted': 10,
#          'women': 10,
#          'intimidate': 10,
#          'eyes': 10,
#          'hours': 10,
#          'safe': 10,
#          'eat': 10,
#          'levity': 10,
#          'vs': 10,
#          '6': 10,
#          'lips': 10,
#          'finally': 10,
#          'months': 10,
#          'road': 10,
#          'girls': 10,
#          'living': 10,
#          'order': 10,
#          'rejoicing': 10,
#          '🔥': 10,
#          'waiting': 10,
#          'TV': 10,
#          'Friday': 10,
#          'expect': 10,
#          'lonely': 10,
#          'cheery': 10,
#          'gun': 10,
#          'pleasing': 10,
#          'social': 10,
#          'frown': 10,
#          'gave': 10,
#          'provoke': 10,
#          'deal': 10,
#          'read': 10,
#          'movie': 10,
#          'holiday': 10,
#          'goes': 10,
#          'blood': 10,
#          'smiling': 10,
#          'Paul': 10,
#          'far': 10,
#          'food': 10,
#          'thinking': 10,
#          'anymore': 10,
#          'ready': 10,
#          'Look': 9,
#          'coming': 9,
#          'soon': 9,
#          'hand': 9,
#          'bed': 9,
#          'episode': 9,
#          'forever': 9,
#          'spent': 9,
#          'inside': 9,
#          'soul': 9,
#          'ppl': 9,
#          'bright': 9,
#          'America': 9,
#          '1st': 9,
#          'dude': 9,
#          'Americans': 9,
#          'Hey': 9,
#          '2016': 9,
#          'place': 9,
#          'short': 9,
#          'power': 9,
#          'Good': 9,
#          'ago': 9,
#          'ages': 9,
#          'website': 9,
#          'holding': 9,
#          'business': 9,
#          'child': 9,
#          'scary': 9,
#          'paid': 9,
#          'death': 9,
#          'online': 9,
#          'send': 9,
#          'Charlotte': 9,
#          'party': 9,
#          'parents': 9,
#          'Got': 9,
#          'biggest': 9,
#          'damn': 9,
#          'film': 9,
#          '😑': 9,
#          'story': 9,
#          'flight': 9,
#          'U': 9,
#          'match': 9,
#          'contact': 9,
#          '£': 9,
#          'bb18': 9,
#          'post': 9,
#          'wonder': 9,
#          'points': 9,
#          'fan': 9,
#          'player': 9,
#          'Yo': 9,
#          'later': 9,
#          'pure': 9,
#          'store': 9,
#          'looked': 8,
#          'vote': 8,
#          'agree': 8,
#          'nd': 8,
#          'honestly': 8,
#          'matter': 8,
#          'taken': 8,
#          'attempt': 8,
#          'resentment': 8,
#          'beautiful': 8,
#          'sense': 8,
#          'age': 8,
#          'early': 8,
#          'wanted': 8,
#          'plus': 8,
#          'huff': 8,
#          'fast': 8,
#          'kids': 8,
#          'cheerfully': 8,
#          'book': 8,
#          'dreams': 8,
#          'centre': 8,
#          'situation': 8,
#          'chance': 8,
#          'optimist': 8,
#          'turned': 8,
#          'sort': 8,
#          'perfect': 8,
#          'nights': 8,
#          'poor': 8,
#          'negative': 8,
#          'lots': 8,
#          'elated': 8,
#          'snapchat': 8,
#          'looting': 8,
#          'mirth': 8,
#          'children': 8,
#          'blacks': 8,
#          'tv': 8,
#          '💘': 8,
#          '😅': 8,
#          'Rooney': 8,
#          'app': 8,
#          'absolute': 8,
#          'sit': 8,
#          'door': 8,
#          '12': 8,
#          'moving': 8,
#          'milk': 8,
#          'forget': 8,
#          'reason': 8,
#          'Nicole': 8,
#          'respect': 8,
#          'ya': 8,
#          'crap': 8,
#          'hot': 8,
#          'email': 8,
#          'writing': 8,
#          'success': 8,
#          'different': 8,
#          '😢': 8,
#          'realize': 8,
#          'sound': 8,
#          'fans': 8,
#          'happens': 8,
#          'extra': 8,
#          'fume': 8,
#          'destroy': 8,
#          'speak': 8,
#          'cute': 7,
#          'bitch': 7,
#          'USA': 7,
#          'won': 7,
#          'low': 7,
#          'self': 7,
#          'forgot': 7,
#          'infuriate': 7,
#          'reading': 7,
#          'air': 7,
#          'Val': 7,
#          'movies': 7,
#          'heyday': 7,
#          'ways': 7,
#          'race': 7,
#          'non': 7,
#          'aggravate': 7,
#          'truly': 7,
#          'experience': 7,
#          'final': 7,
#          'cover': 7,
#          'entire': 7,
#          'annoyed': 7,
#          '😷': 7,
#          'super': 7,
#          'sweet': 7,
#          'rejoice': 7,
#          'major': 7,
#          'question': 7,
#          'process': 7,
#          'Texans': 7,
#          'meet': 7,
#          'gloom': 7,
#          'card': 7,
#          'forward': 7,
#          'awesome': 7,
#          '30': 7,
#          'peace': 7,
#          'dumb': 7,
#          'dog': 7,
#          'Police': 7,
#          'incense': 7,
#          'listening': 7,
#          'trash': 7,
#          '😘': 7,
#          'knew': 7,
#          'affliction': 7,
#          '8': 7,
#          'Black': 7,
#          'fight': 7,
#          'bill': 7,
#          'terrific': 7,
#          'yes': 7,
#          'exactly': 7,
#          'lying': 7,
#          'ticket': 7,
#          'series': 7,
#          'till': 7,
#          '🤔': 7,
#          'open': 7,
#          'stopped': 7,
#          'facts': 7,
#          'names': 7,
#          'swear': 7,
#          'LOVE': 7,
#          'deep': 7,
#          'Obama': 7,
#          'control': 7,
#          'John': 7,
#          'pick': 7,
#          'etc': 7,
#          'Omg': 7,
#          'cut': 7,
#          'awkward': 7,
#          'tried': 7,
#          '😕': 7,
#          'meant': 7,
#          'ones': 7,
#          'second': 7,
#          'smh': 7,
#          'Michelle': 7,
#          'WTF': 7,
#          'fuckin': 7,
#          'red': 7,
#          'interview': 7,
#          'cops': 7,
#          'nation': 7,
#          'tiff': 7,
#          'pm': 7,
#          'hearty': 7,
#          'faith': 7,
#          'w/': 7,
#          'dying': 7,
#          'obviously': 7,
#          'problems': 7,
#          'y': 7,
#          'chirp': 7,
#          'knows': 7,
#          'CharlotteProtest': 7,
#          'went': 7,
#          'irate': 7,
#          'protest': 7,
#          'line': 7,
#          'fright': 7,
#          'info': 7,
#          'sent': 7,
#          'mood': 7,
#          'dismal': 7,
#          'scene': 7,
#          'joyous': 7,
#          'Hell': 7,
#          'leadership': 6,
#          'college': 6,
#          'Indian': 6,
#          'dry': 6,
#          'worth': 6,
#          'definitely': 6,
#          'difference': 6,
#          '11': 6,
#          'surprised': 6,
#          'suppose': 6,
#          'dropped': 6,
#          'letting': 6,
#          'Hope': 6,
#          'rock': 6,
#          'smoke': 6,
#          'force': 6,
#          'mope': 6,
#          'worried': 6,
#          'easy': 6,
#          'drive': 6,
#          'decide': 6,
#          '9': 6,
#          'yr': 6,
#          'broke': 6,
#          'Maybe': 6,
#          'positive': 6,
#          'yesterday': 6,
#          'starts': 6,
#          'favorite': 6,
#          'single': 6,
#          'reality': 6,
#          '18': 6,
#          'involved': 6,
#          'New': 6,
#          'memories': 6,
#          'losers': 6,
#          '💔': 6,
#          'shut': 6,
#          'fake': 6,
#          'cheerful': 6,
#          'group': 6,
#          'woke': 6,
#          'character': 6,
#          'starting': 6,
#          '💦': 6,
#          'Feeling': 6,
#          'catch': 6,
#          'son': 6,
#          'shooting': 6,
#          'drunk': 6,
#          'depressed': 6,
#          'debate': 6,
#          'met': 6,
#          'style': 6,
#          'City': 6,
#          'Dear': 6,
#          'bus': 6,
#          'pull': 6,
#          'walk': 6,
#          'bet': 6,
#          'UNGA': 6,
#          'shows': 6,
#          'cool': 6,
#          'weekend': 6,
#          'dangerous': 6,
#          'tweets': 6,
#          'telling': 6,
#          'stay': 6,
#          'rules': 6,
#          'city': 6,
#          'box': 6,
#          'office': 6,
#          'fine': 6,
#          'balls': 6,
#          'pain': 6,
#          'football': 6,
#          'assume': 6,
#          'mufc': 6,
#          'dead': 6,
#          'Snapchat': 6,
#          'pics': 6,
#          'completely': 6,
#          'support': 6,
#          'Yes': 6,
#          'key': 6,
#          'frowning': 6,
#          'dad': 6,
#          'coffee': 6,
#          'answer': 6,
#          'simple': 6,
#          'floor': 6,
#          'able': 6,
#          'train': 6,
#          'laughing': 6,
#          'stand': 6,
#          'kitchen': 6,
#          'v': 6,
#          'garbage': 6,
#          'Getting': 6,
#          'photo': 6,
#          'haha': 6,
#          'set': 6,
#          'lack': 6,
#          'Literally': 6,
#          'BB18': 6,
#          'rape': 6,
#          'Rojo': 6,
#          'reverse': 6,
#          'held': 6,
#          'queue': 6,
#          'mistake': 6,
#          'fall': 6,
#          'animosity': 6,
#          'putting': 6,
#          'tantrums': 6,
#          'sucks': 6,
#          'campaign': 6,
#          'laugh': 6,
#          'LOL': 6,
#          'respond': 6,
#          'Candice': 6,
#          'song': 6,
#          'radio': 6,
#          'irritation': 6,
#          'mother': 6,
#          'pic': 6,
#          'expected': 6,
#          'comedy': 6,
#          'turns': 6,
#          'nigga': 6,
#          'Mary': 6,
#          'kik': 6,
#          'young': 6,
#          'calling': 6,
#          'gym': 6,
#          'missed': 6,
#          'earth': 6,
#          'revolting': 6,
#          'voice': 6,
#          'spider': 6,
#          'tho': 6,
#          'important': 6,
#          'Bloody': 6,
#          'somebody': 6,
#          '\\n': 6,
#          'zero': 6,
#          'stomach': 6,
#          'picture': 6,
#          'president': 6,
#          'hath': 6,
#          'exact': 6,
#          'sulk': 6,
#          'games': 6,
#          'BS': 6,
#          'scrum': 6,
#          'exhausted': 5,
#          'Pak': 5,
#          'recent': 5,
#          'possible': 5,
#          'changing': 5,
#          'stress': 5,
#          'btw': 5,
#          'Manchester': 5,
#          'article': 5,
#          'normal': 5,
#          '40': 5,
#          'politics': 5,
#          'Need': 5,
#          'Birthday': 5,
#          'FF': 5,
#          'supporting': 5,
#          'protests': 5,
#          'clown': 5,
#          'bought': 5,
#          'bottle': 5,
#          'nope': 5,
#          'justice': 5,
#          'gt': 5,
#          'despite': 5,
#          'seek': 5,
#          'North': 5,
#          'offensive': 5,
#          'focus': 5,
#          'town': 5,
#          'grieve': 5,
#          'Pretty': 5,
#          'blind': 5,
#          '2nd': 5,
#          '3rd': 5,
#          'chances': 5,
#          'advice': 5,
#          'wearing': 5,
#          'wall': 5,
#          'adult': 5,
#          'ability': 5,
#          'wife': 5,
#          'current': 5,
#          'imagine': 5,
#          'wind': 5,
#          'policy': 5,
#          'crimes': 5,
#          'World': 5,
#          'sister': 5,
#          'came': 5,
#          'rich': 5,
#          'decided': 5,
#          'losing': 5,
#          'rude': 5,
#          'disheartened': 5,
#          'luck': 5,
#          'sitting': 5,
#          '☹': 5,
#          'version': 5,
#          'hurt': 5,
#          'murder': 5,
#          'hatred': 5,
#          'distrust': 5,
#          'round': 5,
#          'drinking': 5,
#          'sees': 5,
#          'opportunity': 5,
#          'shall': 5,
#          'fret': 5,
#          '️️': 5,
#          'fucked': 5,
#          'parking': 5,
#          'blame': 5,
#          'born': 5,
#          'Celtic': 5,
#          'punch': 5,
#          'growing': 5,
#          'annoying': 5,
#          '\\n\\n': 5,
#          'finish': 5,
#          'jump': 5,
#          'spirit': 5,
#          'keeps': 5,
#          'cup': 5,
#          'pressure': 5,
#          'juggle': 5,
#          'pun': 5,
#          'punny': 5,
#          'gay': 5,
#          'Wish': 5,
#          'fearing': 5,
#          'services': 5,
#          'energy': 5,
#          'United': 5,
#          'Jesus': 5,
#          'dm': 5,
#          '🙂': 5,
#          '😬': 5,
#          'promise': 5,
#          '😆': 5,
#          'inflame': 5,
#          'wonderful': 5,
#          'everybody': 5,
#          'express': 5,
#          'MHChat': 5,
#          '🏻': 5,
#          'Saturday': 5,
#          'secret': 5,
#          'written': 5,
#          'Honestly': 5,
#          'Lord': 5,
#          'em': 5,
#          'challenge': 5,
#          'Fucking': 5,
#          'likes': 5,
#          'Anger': 5,
#          'shitty': 5,
#          'distracting': 5,
#          'wake': 5,
#          'chuckle': 5,
#          'Glad': 5,
#          'near': 5,
#          'brought': 5,
#          'Pizza': 5,
#          'followers': 5,
#          'Think': 5,
#          'jazz': 5,
#          'White': 5,
#          'anti': 5,
#          ...})

# %%
# 選擇最常見的 5000 個單詞作為詞彙表
most_common_words = word_freq.most_common(5000)
# 建立詞彙到索引的映射 e.g. hello -> 1, like -> 2 ...
vocab = {word[0]: idx for idx, word in enumerate(most_common_words)}

[(k, v) for k, v in vocab.items() if v == 4999]
# Out:
# [('Paul.should', 4999)]

# %%
# 轉換單詞為索引，超出詞彙表的單詞用佔位索引 5001 代替 因為我們會收集前 5000 個單詞，如果沒有在裡面則用 5001 代替
placeholder_index = 5000
indexed_dataset = []
for tweet in train_dataset:
    indexed_words = []
    for token in nlp(tweet):
        if not token.is_punct and not token.is_stop and not token.is_space:
            word = token.text
            if word in vocab:
                indexed_words.append(vocab[word])
            else:
                indexed_words.append(placeholder_index)
    indexed_dataset.append(indexed_words)

# 打印轉換後的數據
print(indexed_dataset)
# Out:
# [[2013, 3615, 269, 3616, 3617, 1426, 717, 86], [1069, 339, 2014, 2015, 44, 2016], [606, 3618, 340, 162, 3619, 3620, 2017, 3621], [3622, 25, 3623, 25, 196, 3624, 537, 3625], [163, 52, 9, 341, 3626, 140, 1427, 3627], [0, 1428, 380, 270, 3628, 607, 7, 297, 2018], [2019, 3629, 1429, 342, 1070, 718, 3630, 343, 872, 381, 718], [3631, 271, 3632, 1430, 3633, 344, 3634, 210], [0, 2020, 42, 2021, 2022, 17, 3635], [0, 480, 2023, 433], [0, 0, 608, 2024, 74, 10, 111, 609, 71, 39, 244], [3636, 3637, 2, 719, 3638, 272, 3639, 211, 0, 3640, 3641, 873, 65, 3642, 53, 273], [141, 1071, 3643, 720, 3644, 874, 382, 2025, 1431, 245, 1432, 2, 224, 116, 23], [25, 2026, 0, 2027], [3645, 1072, 3646, 383, 3647], [0, 3648, 538, 539, 298, 1433, 538, 1434, 20, 2028], [0, 3649, 610, 611, 721, 3650, 1073, 3651, 3652, 101, 274, 3653, 3654], [1435, 3655, 2029, 14, 117, 176, 1074, 3656], [0, 3657, 39, 46, 118, 3658, 2030, 125, 118, 3659], [0, 0, 0, 3660, 2031, 1436, 3661, 1437, 3662, 3663, 49], [212, 3664, 26, 1438, 3665, 118], [875, 876, 1439, 95, 877, 3666, 58, 177, 3667, 2032], [28, 722, 77, 3668, 3669, 2033, 2033, 3670, 3671, 2034, 3672], [0, 1440, 1441, 246, 299, 3673, 43, 5, 434], [0, 0, 3674, 31, 39], [0, 5, 3675, 9, 53, 2035, 540, 3676, 1442, 9, 612, 435, 723, 878, 1442, 540, 345], [3677, 346], [3678, 3679, 1075, 3680, 3681, 1076, 3682, 384, 3683, 613, 3684], [213, 178, 150, 66, 344, 102, 1443, 3685, 3686, 45, 142], [40, 40, 2036, 18, 481, 482, 436, 3687, 3688, 40], [197, 143, 141, 103, 3689, 84, 141, 3690], [2037, 1077, 541, 380, 2038], [0, 59, 1078, 3691, 300, 45, 2039, 384, 119, 3692, 3693], [0, 0, 3694, 54, 1079, 3695, 2040, 3696, 3697, 301], [3698, 3699, 78, 164, 275, 3700, 542, 3701], [879, 2041, 96], [340, 2042, 437, 1444, 614, 880, 302, 2043, 1445, 385], [13, 303, 3702, 3703, 3704], [2044, 25, 196, 1, 214, 724, 225, 75, 60], [0, 543, 3705, 1446, 615, 1447, 881, 17, 1080, 3706], [0, 179, 144, 3, 180, 1081, 725, 347, 726, 75, 3707], [2045, 727, 3708, 304, 226], [386, 247, 1448, 387, 32, 1449, 95, 67, 348, 882, 79, 1082, 76], [2046, 2047, 544, 438, 3709, 3710, 3711, 2048, 3712, 3713, 3714], [22, 8, 24, 151, 3715, 3716, 483, 388, 0, 3717, 162, 2049, 0], [349, 1450, 3718, 3719, 2050, 3720], [0, 3721, 3722, 152, 3723, 3724], [3725, 3726, 3727, 484, 2051, 545, 3728, 3729, 132, 80, 7, 883], [3730, 126, 3731, 126, 2052, 33, 14, 3732, 1, 3733, 3734, 0, 4], [3735, 439, 720, 181, 145, 1, 3736, 3737], [119, 120, 1, 302, 1083, 2053, 3738], [0, 3739, 18, 1084, 3740, 1451, 0, 3741, 72, 2054, 18, 215, 3742, 38, 2055, 3743], [0, 182, 2056, 165, 1452, 97, 213, 15, 6], [616, 7, 45, 127, 3744, 2057, 3745, 45, 53, 121], [0, 3746, 3747, 3748, 3749, 10, 1453, 1085, 227, 546, 11], [0, 0, 3750, 3751, 3752, 3753, 18, 81, 305, 3754, 3755, 3756, 3757, 3758, 17], [389, 3759, 3760, 485, 728, 2058, 54, 0, 50], [884, 30, 3761, 40], [3762, 3763, 729, 3764, 10, 2059, 612, 50, 12, 3765], [0, 0, 248, 270, 486, 2060, 104, 228, 2061], [166, 112, 2062, 23], [0, 0, 0, 3766, 85, 56, 3767, 25, 43], [0, 487, 18, 25, 440, 2063, 2064, 2065, 2066, 2067, 2068], [386, 885, 1086, 27, 3768, 3769, 3770, 3771], [1087, 57, 1454, 1455, 16, 488, 19, 1456], [276, 3772, 3773, 167], [886, 3774, 3775, 47, 2, 730, 3776, 3777, 489, 2, 2069, 3778, 3779, 3780], [0, 0, 3781, 229, 547, 53, 887, 2070, 3782, 3783, 490, 3784, 3785, 888, 3786], [1453, 617, 67, 1, 144, 104, 79], [1, 3787, 1457, 1088, 1458, 306, 30, 3788, 3789, 87, 25, 34], [0, 162, 3790], [307, 29, 731], [3791, 2071, 197, 344, 1459, 2072, 7, 17, 1089, 37, 197, 1460, 344], [0, 198, 618, 2073, 3792, 548, 3793, 549, 2074], [0, 1090, 3794, 390, 2075, 59, 2076], [0, 0, 0, 3795, 3796, 3797, 438, 732, 1461, 889], [1, 183, 26, 184, 13, 3798, 230, 277, 2077, 1091, 3799], [3800, 0, 3801, 34, 3802, 15, 1462, 27, 0, 890, 3803, 3804], [491, 128, 2078, 1092, 3805, 3806, 68, 4, 2079, 1463, 72, 12, 82], [0, 619, 1464, 15, 274, 733], [1087, 57, 1454, 1455, 16, 488, 19, 36, 1456], [2080, 3807, 185, 2, 3808, 485, 2081, 2, 346, 3809], [216, 29, 30, 1093, 3810, 249], [0, ...

# %% [markdown]
# - Follow the example described here. Use the same architecture, but:
#   - only use the last output of the LSTM in the loss function
#   - use an embedding dim of 128
#   - use a hidden dim of 256.

# %%
mapping = dict(zip(mapping_pd[0], mapping_pd[1]))
mapping
# Out:
# {0: 'anger', 1: 'joy', 2: 'optimism', 3: 'sadness'}

# %%
EMBEDDING_DIM = 128 # 將word轉換成維度為128的向量
HIDDEN_DIM = 256 # 在RNN或LSTM中模型中隱藏曾神經元的數量大小
word_to_ix = vocab # 詞彙表
tag_to_ix = mapping # 標籤表

# %%
class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size, dropout=0.0):
        super(LSTMTagger, self).__init__()
        self.hidden_dim = hidden_dim
        # 把每個詞都轉換成詞向量
        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)

        # The LSTM takes word embeddings as inputs, and outputs hidden states
        # with dimensionality hidden_dim.
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, dropout=dropout)

        # The linear layer that maps from hidden state space to tag space
        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence) # 將輸入的句子中的每個詞都轉換成詞向量
        lstm_out, _ = self.lstm(embeds.view(len(sentence), 1, -1)) # 將詞向量作為LSTM模型的輸入 得到LSTM曾的輸出和隱藏狀態
        # Take only the last output of the LSTM
        last_output = lstm_out[-1].view(1, -1)  # Selecting the last output
        tag_space = self.hidden2tag(last_output) # 將LSTM模型的最後輸出轉換成 詞標籤 空間
        tag_scores = F.log_softmax(tag_space, dim=1)
        return tag_scores

# %%
len(word_to_ix)+1
# Out:
# 5001

# %%
# vocab_size 要添加 1 因為如果 sentence 中有出現沒在 vocab 中的單字，使用 5000 來代替，所以要加 1
model = LSTMTagger(EMBEDDING_DIM, HIDDEN_DIM, len(word_to_ix)+1, len(tag_to_ix))
loss_function = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
exp_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %%
# for sentence to sequence 
def prepare_sentence_sequence(seq, to_ix):
    idx = []
    # use spacy to tokenize the sentence 
    for token in nlp(seq):
        # filter out the punctuation and stop words and space 
        if not token.is_punct and not token.is_stop and not token.is_space:
            word = token.text
            # if the token is in the top 5000 words in the vocab, add its index to the list
            if word in to_ix:
                idx.append(to_ix[word])
            else:
                # else add the index of the placeholder token
                idx.append(placeholder_index)
    return torch.tensor(idx, dtype=torch.long)

# %%
def one_hot_encode(val, to_ix):
    result = []
    for k, v in to_ix.items(): 
        if val == k:
            result.append(1)
        else:
            result.append(0)
    return torch.tensor(result, dtype=torch.float32)

# %%
print(mapping)
print(one_hot_encode(2, tag_to_ix))
# Out:
# {0: 'anger', 1: 'joy', 2: 'optimism', 3: 'sadness'}
# tensor([0., 0., 1., 0.])

# %%
# See what the scores are before training
# Note that element i,j of the output is the score for tag j for word i. ; j有3個、i有5個字，i, j 表示第i個字的第j個tag的分數
# Here we don't need to train, so the code is wrapped in torch.no_grad()
sentence_idx = 1
with torch.no_grad():
    inputs = prepare_sentence_sequence(train_dataset[sentence_idx], word_to_ix)
    labels = one_hot_encode(train_label_pd[0][sentence_idx], tag_to_ix)
    outputs = model(inputs)
    _, preds = torch.max(outputs, 1)
    result_idx = torch.argmax(outputs).item()
    loss = loss_function(outputs[0], labels)

    print(f'First Sentense = {train_dataset[sentence_idx]}')
    print(f'Sentense to tensor = {inputs}')
    print(f'Sentense of result to tensor = {labels}')
    print(f'tag_scores = {outputs}')
    print(f'loss = {loss}')
    print(f'preds = {preds}')
    print(f'result = {result_idx}, ans = {train_label_pd[0][sentence_idx]}')
# Out:
# First Sentense = My roommate: it's okay that we can't spell because we have autocorrect. #terrible #firstworldprobs
# Sentense to tensor = tensor([1070,  340, 2015, 2016,   45, 2017])
# Sentense of result to tensor = tensor([1., 0., 0., 0.])
# tag_scores = tensor([[-1.3280, -1.4272, -1.4998, -1.3026]])
# loss = 1.32795250415802
# preds = tensor([3])
# result = 3, ans = 0

# %%
dataloaders = {'train': train_dataset, 'test': test_dataset}
resultloaders = {'train': train_label_pd[0].tolist(), 'test': test_label_pd[0].tolist()}
dataset_sizes = {x: len(dataloaders[x]) for x in ['train', 'test']}
dataset_sizes
# Out:
# {'train': 3257, 'test': 1421}

# %%
phase = 'train'

len(resultloaders[phase])
# Out:
# 3257

# %%
def train_model(model, criterion, optimizer, scheduler, num_epochs=1):
    since = time.time()
    with TemporaryDirectory() as tempdir:
        best_model_params_path = os.path.join(tempdir, 'best_model_params.pt')

        torch.save(model.state_dict(), best_model_params_path)
        best_acc = 0.0

        for epoch in range(num_epochs):
            print(f'Epoch {epoch}/{num_epochs - 1}')
            print('-' * 10)

            # Each epoch has a training and validation phase
            for phase in ['train', 'test']:
                if phase == 'train':
                    model.train()
                else: 
                    model.eval()
                
                running_loss = 0.0
                running_corrects = 0

                # Iterate over data.
                for input, label in zip(dataloaders[phase], resultloaders[phase]):
                    inputs_vector = prepare_sentence_sequence(input, word_to_ix)
                    labels_vector = one_hot_encode(label, tag_to_ix)
                    
                    # zero the parameter gradients
                    optimizer.zero_grad()

                    # forward
                    # track history if only in train
                    with torch.set_grad_enabled(phase == 'train'):
                        outputs = model(inputs_vector) # 取得針對每個emotion的預測結果tensor (e.g. tensor([[-1.3948, -1.4476, -1.3804, -1.3261]]))
                        pred = torch.argmax(outputs).item() # 取得最大值的index (e.g. 2)
                        loss = criterion(outputs[0], labels_vector) # 外面還有一層，只需取得內層 [-1.3948, -1.4476, -1.3804, -1.3261] 與 [0, 0, 1, 0] 的計算loss

                        # backward + optimize only if in training phase
                        if phase == 'train':
                            loss.backward()
                            optimizer.step()

                    # statistics
                    running_loss += loss.item()
                    if pred == label:
                        running_corrects += 1

                if phase == 'train':
                    scheduler.step()

                epoch_loss = running_loss / dataset_sizes[phase]
                epoch_acc = running_corrects / dataset_sizes[phase]
                print(f'{phase} Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f} Time elapsed: {round((time.time() - since))} sec.')
                
                # deep copy the model
                if phase == 'test' and epoch_acc > best_acc:
                    best_acc = epoch_acc
                    torch.save(model.state_dict(), best_model_params_path)

            print()

        time_elapsed = time.time() - since
        print(f'Training complete in {time_elapsed // 60:.0f}m {time_elapsed % 60:.0f}s')
        print(f'Best val Acc: {best_acc:4f}')

        # load best model weights
        model.load_state_dict(torch.load(best_model_params_path))
    return model

# %%
model = train_model(model, loss_function, optimizer, exp_lr_scheduler, num_epochs=30)
# Out:
# Epoch 0/29
# ----------
# train Loss: 1.2157 Acc: 0.4642 Time elapsed: 25 sec.
# test Loss: 1.2095 Acc: 0.4553 Time elapsed: 32 sec.
#
# Epoch 1/29
# ----------
# train Loss: 1.1019 Acc: 0.5333 Time elapsed: 58 sec.
# test Loss: 1.1816 Acc: 0.4708 Time elapsed: 65 sec.
#
# Epoch 2/29
# ----------
# train Loss: 1.0151 Acc: 0.5812 Time elapsed: 92 sec.
# test Loss: 1.1603 Acc: 0.4898 Time elapsed: 99 sec.
#
# Epoch 3/29
# ----------
# train Loss: 0.9054 Acc: 0.6386 Time elapsed: 125 sec.
# test Loss: 1.1535 Acc: 0.5201 Time elapsed: 131 sec.
#
# Epoch 4/29
# ----------
# train Loss: 0.7659 Acc: 0.7000 Time elapsed: 157 sec.
# test Loss: 1.1363 Acc: 0.5348 Time elapsed: 164 sec.
#
# Epoch 5/29
# ----------
# train Loss: 0.6118 Acc: 0.7753 Time elapsed: 191 sec.
# test Loss: 1.1445 Acc: 0.5531 Time elapsed: 198 sec.
#
# Epoch 6/29
# ----------
# train Loss: 0.4562 Acc: 0.8410 Time elapsed: 225 sec.
# test Loss: 1.2045 Acc: 0.5714 Time elapsed: 232 sec.
#
# Epoch 7/29
# ----------
# train Loss: 0.2953 Acc: 0.9137 Time elapsed: 258 sec.
# test Loss: 1.1451 Acc: 0.5918 Time elapsed: 265 sec.
#
# Epoch 8/29
# ----------
# train Loss: 0.2588 Acc: 0.9315 Time elapsed: 292 sec.
# test Loss: 1.1531 Acc: 0.5961 Time elapsed: 299 sec.
#
# Epoch 9/29
# ----------
# train Loss: 0.2359 Acc: 0.9398 Time elapsed: 326 sec.
# test Loss: 1.1681 Acc: 0.5961 Time elapsed: 332 sec.
#
# Epoch 10/29
# ----------
# train Loss: 0.2175 Acc: 0.9509 Time elapsed: 360 sec.
# test Loss: 1.1861 Acc: 0.5947 Time elapsed: 367 sec.
#
# Epoch 11/29
# ----------
# train Loss: 0.2019 Acc: 0.9570 Time elapsed: 393 sec.
# test Loss: 1.2060 Acc: 0.5961 Time elapsed: 400 sec.
#
# Epoch 12/29
# ----------
# train Loss: 0.1880 Acc: 0.9613 Time elapsed: 426 sec.
# test Loss: 1.2270 Acc: 0.5989 Time elapsed: 433 sec.
#
# Epoch 13/29
# ----------
# train Loss: 0.1755 Acc: 0.9650 Time elapsed: 460 sec.
# test Loss: 1.2487 Acc: 0.5996 Time elapsed: 467 sec.
#
# Epoch 14/29
# ----------
# train Loss: 0.1619 Acc: 0.9690 Time elapsed: 494 sec.
# test Loss: 1.2382 Acc: 0.5947 Time elapsed: 501 sec.
#
# Epoch 15/29
# ----------
# train Loss: 0.1598 Acc: 0.9699 Time elapsed: 529 sec.
# test Loss: 1.2387 Acc: 0.5954 Time elapsed: 536 sec.
#
# Epoch 16/29
# ----------
# train Loss: 0.1585 Acc: 0.9711 Time elapsed: 564 sec.
# test Loss: 1.2409 Acc: 0.5947 Time elapsed: 571 sec.
#
# Epoch 17/29
# ----------
# train Loss: 0.1573 Acc: 0.9711 Time elapsed: 599 sec.
# test Loss: 1.2434 Acc: 0.5947 Time elapsed: 606 sec.
#
# Epoch 18/29
# ----------
# train Loss: 0.1561 Acc: 0.9718 Time elapsed: 635 sec.
# test Loss: 1.2460 Acc: 0.5947 Time elapsed: 642 sec.
#
# Epoch 19/29
# ----------
# train Loss: 0.1550 Acc: 0.9724 Time elapsed: 670 sec.
# test Loss: 1.2485 Acc: 0.5947 Time elapsed: 676 sec.
#
# Epoch 20/29
# ----------
# train Loss: 0.1539 Acc: 0.9733 Time elapsed: 705 sec.
# test Loss: 1.2511 Acc: 0.5954 Time elapsed: 712 sec.
#
# Epoch 21/29
# ----------
# train Loss: 0.1523 Acc: 0.9730 Time elapsed: 739 sec.
# test Loss: 1.2510 Acc: 0.5954 Time elapsed: 746 sec.
#
# Epoch 22/29
# ----------
# train Loss: 0.1522 Acc: 0.9733 Time elapsed: 773 sec.
# test Loss: 1.2509 Acc: 0.5954 Time elapsed: 780 sec.
#
# Epoch 23/29
# ----------
# train Loss: 0.1521 Acc: 0.9733 Time elapsed: 808 sec.
# test Loss: 1.2510 Acc: 0.5947 Time elapsed: 815 sec.
#
# Epoch 24/29
# ----------
# train Loss: 0.1520 Acc: 0.9733 Time elapsed: 842 sec.
# test Loss: 1.2510 Acc: 0.5947 Time elapsed: 849 sec.
#
# Epoch 25/29
# ----------
# train Loss: 0.1519 Acc: 0.9733 Time elapsed: 877 sec.
# test Loss: 1.2511 Acc: 0.5947 Time elapsed: 884 sec.
#
# Epoch 26/29
# ----------
# train Loss: 0.1517 Acc: 0.9736 Time elapsed: 912 sec.
# test Loss: 1.2513 Acc: 0.5954 Time elapsed: 920 sec.
#
# Epoch 27/29
# ----------
# train Loss: 0.1516 Acc: 0.9739 Time elapsed: 949 sec.
# test Loss: 1.2514 Acc: 0.5954 Time elapsed: 955 sec.
#
# Epoch 28/29
# ----------
# train Loss: 0.1515 Acc: 0.9736 Time elapsed: 984 sec.
# test Loss: 1.2514 Acc: 0.5954 Time elapsed: 991 sec.
#
# Epoch 29/29
# ----------
# train Loss: 0.1515 Acc: 0.9736 Time elapsed: 1019 sec.
# test Loss: 1.2514 Acc: 0.5954 Time elapsed: 1025 sec.
#
# Training complete in 17m 5s
# Best val Acc: 0.599578

# %%
class GRUTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size, dropout=0.0):
        super(GRUTagger, self).__init__()
        self.hidden_dim = hidden_dim
        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)

        # The LSTM takes word embeddings as inputs, and outputs hidden states
        # with dimensionality hidden_dim.
        self.gru = nn.GRU(embedding_dim, hidden_dim, dropout=dropout)

        # The linear layer that maps from hidden state space to tag space
        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence) # 將輸入的句子中的每個詞都轉換成詞向量
        lstm_out, _ = self.gru(embeds.view(len(sentence), 1, -1)) # 將詞向量作為LSTM模型的輸入 得到LSTM曾的輸出和隱藏狀態
        # Take only the last output of the LSTM
        last_output = lstm_out[-1].view(1, -1)  # Selecting the last output
        tag_space = self.hidden2tag(last_output) # 將LSTM模型的最後輸出轉換成 詞標籤 空間
        tag_scores = F.log_softmax(tag_space, dim=1)
        return tag_scores

# %%
# vocab_size 要添加 2 因為如果 sentence 中有出現沒在 vocab 中的單字，使用 5001 來代替，所以要加 1
modelGRU = GRUTagger(EMBEDDING_DIM, HIDDEN_DIM, len(word_to_ix)+1, len(tag_to_ix), dropout=0.5)
loss_function_gru = nn.CrossEntropyLoss()
optimizer_gru = optim.SGD(modelGRU.parameters(), lr=0.001, momentum=0.9)
exp_lr_scheduler_gru = lr_scheduler.StepLR(optimizer_gru, step_size=7, gamma=0.1)

# %%
modelGRU = train_model(modelGRU, loss_function_gru, optimizer_gru, exp_lr_scheduler_gru, num_epochs=30)
# Out:
# Epoch 0/29
# ----------
# train Loss: 1.1921 Acc: 0.4842 Time elapsed: 27 sec.
# test Loss: 1.2221 Acc: 0.4588 Time elapsed: 34 sec.
#
# Epoch 1/29
# ----------
# train Loss: 1.0732 Acc: 0.5502 Time elapsed: 62 sec.
# test Loss: 1.1963 Acc: 0.4701 Time elapsed: 69 sec.
#
# Epoch 2/29
# ----------
# train Loss: 0.9747 Acc: 0.5972 Time elapsed: 96 sec.
# test Loss: 1.1551 Acc: 0.5053 Time elapsed: 104 sec.
#
# Epoch 3/29
# ----------
# train Loss: 0.8445 Acc: 0.6702 Time elapsed: 131 sec.
# test Loss: 1.1211 Acc: 0.5327 Time elapsed: 138 sec.
#
# Epoch 4/29
# ----------
# train Loss: 0.6843 Acc: 0.7393 Time elapsed: 166 sec.
# test Loss: 1.1305 Acc: 0.5707 Time elapsed: 173 sec.
#
# Epoch 5/29
# ----------
# train Loss: 0.5111 Acc: 0.8142 Time elapsed: 200 sec.
# test Loss: 1.2057 Acc: 0.5672 Time elapsed: 207 sec.
#
# Epoch 6/29
# ----------
# train Loss: 0.3387 Acc: 0.8901 Time elapsed: 234 sec.
# test Loss: 1.3223 Acc: 0.5693 Time elapsed: 241 sec.
#
# Epoch 7/29
# ----------
# train Loss: 0.1779 Acc: 0.9472 Time elapsed: 269 sec.
# test Loss: 1.2429 Acc: 0.5989 Time elapsed: 275 sec.
#
# Epoch 8/29
# ----------
# train Loss: 0.1393 Acc: 0.9678 Time elapsed: 301 sec.
# test Loss: 1.2442 Acc: 0.6045 Time elapsed: 308 sec.
#
# Epoch 9/29
# ----------
# train Loss: 0.1195 Acc: 0.9788 Time elapsed: 334 sec.
# test Loss: 1.2530 Acc: 0.6024 Time elapsed: 341 sec.
#
# Epoch 10/29
# ----------
# train Loss: 0.1058 Acc: 0.9834 Time elapsed: 367 sec.
# test Loss: 1.2657 Acc: 0.6073 Time elapsed: 374 sec.
#
# Epoch 11/29
# ----------
# train Loss: 0.0952 Acc: 0.9868 Time elapsed: 401 sec.
# test Loss: 1.2804 Acc: 0.6059 Time elapsed: 407 sec.
#
# Epoch 12/29
# ----------
# train Loss: 0.0866 Acc: 0.9896 Time elapsed: 434 sec.
# test Loss: 1.2961 Acc: 0.6045 Time elapsed: 441 sec.
#
# Epoch 13/29
# ----------
# train Loss: 0.0795 Acc: 0.9908 Time elapsed: 467 sec.
# test Loss: 1.3123 Acc: 0.6080 Time elapsed: 474 sec.
#
# Epoch 14/29
# ----------
# train Loss: 0.0719 Acc: 0.9929 Time elapsed: 499 sec.
# test Loss: 1.3123 Acc: 0.6073 Time elapsed: 506 sec.
#
# Epoch 15/29
# ----------
# train Loss: 0.0711 Acc: 0.9936 Time elapsed: 532 sec.
# test Loss: 1.3137 Acc: 0.6066 Time elapsed: 539 sec.
#
# Epoch 16/29
# ----------
# train Loss: 0.0704 Acc: 0.9936 Time elapsed: 566 sec.
# test Loss: 1.3154 Acc: 0.6087 Time elapsed: 573 sec.
#
# Epoch 17/29
# ----------
# train Loss: 0.0698 Acc: 0.9936 Time elapsed: 600 sec.
# test Loss: 1.3172 Acc: 0.6073 Time elapsed: 607 sec.
#
# Epoch 18/29
# ----------
# train Loss: 0.0692 Acc: 0.9939 Time elapsed: 634 sec.
# test Loss: 1.3190 Acc: 0.6073 Time elapsed: 641 sec.
#
# Epoch 19/29
# ----------
# train Loss: 0.0687 Acc: 0.9939 Time elapsed: 668 sec.
# test Loss: 1.3208 Acc: 0.6080 Time elapsed: 675 sec.
#
# Epoch 20/29
# ----------
# train Loss: 0.0682 Acc: 0.9939 Time elapsed: 703 sec.
# test Loss: 1.3225 Acc: 0.6080 Time elapsed: 709 sec.
#
# Epoch 21/29
# ----------
# train Loss: 0.0674 Acc: 0.9948 Time elapsed: 736 sec.
# test Loss: 1.3227 Acc: 0.6080 Time elapsed: 743 sec.
#
# Epoch 22/29
# ----------
# train Loss: 0.0674 Acc: 0.9948 Time elapsed: 769 sec.
# test Loss: 1.3229 Acc: 0.6073 Time elapsed: 775 sec.
#
# Epoch 23/29
# ----------
# train Loss: 0.0673 Acc: 0.9948 Time elapsed: 801 sec.
# test Loss: 1.3230 Acc: 0.6073 Time elapsed: 808 sec.
#
# Epoch 24/29
# ----------
# train Loss: 0.0673 Acc: 0.9948 Time elapsed: 834 sec.
# test Loss: 1.3232 Acc: 0.6073 Time elapsed: 841 sec.
#
# Epoch 25/29
# ----------
# train Loss: 0.0672 Acc: 0.9948 Time elapsed: 868 sec.
# test Loss: 1.3233 Acc: 0.6073 Time elapsed: 874 sec.
#
# Epoch 26/29
# ----------
# train Loss: 0.0672 Acc: 0.9951 Time elapsed: 900 sec.
# test Loss: 1.3235 Acc: 0.6073 Time elapsed: 906 sec.
#
# Epoch 27/29
# ----------
# train Loss: 0.0671 Acc: 0.9951 Time elapsed: 932 sec.
# test Loss: 1.3237 Acc: 0.6073 Time elapsed: 939 sec.
#
# Epoch 28/29
# ----------
# train Loss: 0.0670 Acc: 0.9951 Time elapsed: 964 sec.
# test Loss: 1.3237 Acc: 0.6073 Time elapsed: 971 sec.
#
# Epoch 29/29
# ----------
# train Loss: 0.0670 Acc: 0.9951 Time elapsed: 996 sec.
# test Loss: 1.3237 Acc: 0.6073 Time elapsed: 1003 sec.
#
# Training complete in 16m 43s
# Best val Acc: 0.608726

# %%
# vocab_size 要添加 2 因為如果 sentence 中有出現沒在 vocab 中的單字，使用 5001 來代替，所以要加 1
model_LSTM = LSTMTagger(EMBEDDING_DIM, HIDDEN_DIM, len(word_to_ix)+1, len(tag_to_ix), dropout=0.5)
loss_function_LSTM = nn.CrossEntropyLoss()
optimizer_LSTM = optim.SGD(model_LSTM.parameters(), lr=0.001, momentum=0.9)
exp_lr_scheduler_LSTM = lr_scheduler.StepLR(optimizer_LSTM, step_size=7, gamma=0.1)
# Out:
# /opt/homebrew/lib/python3.11/site-packages/torch/nn/modules/rnn.py:82: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "

# %%
modelLSTM = train_model(model_LSTM, loss_function_LSTM, optimizer_LSTM, exp_lr_scheduler_LSTM, num_epochs=30)
# Out:
# Epoch 0/29
# ----------
# train Loss: 1.2062 Acc: 0.4673 Time elapsed: 27 sec.
# test Loss: 1.1884 Acc: 0.4659 Time elapsed: 34 sec.
#
# Epoch 1/29
# ----------
# train Loss: 1.0779 Acc: 0.5379 Time elapsed: 62 sec.
# test Loss: 1.1504 Acc: 0.4891 Time elapsed: 69 sec.
#
# Epoch 2/29
# ----------
# train Loss: 0.9885 Acc: 0.5840 Time elapsed: 97 sec.
# test Loss: 1.1279 Acc: 0.5236 Time elapsed: 104 sec.
#
# Epoch 3/29
# ----------
# train Loss: 0.8893 Acc: 0.6371 Time elapsed: 132 sec.
# test Loss: 1.1053 Acc: 0.5369 Time elapsed: 139 sec.
#
# Epoch 4/29
# ----------
# train Loss: 0.7683 Acc: 0.7003 Time elapsed: 168 sec.
# test Loss: 1.0772 Acc: 0.5658 Time elapsed: 175 sec.
#
# Epoch 5/29
# ----------
# train Loss: 0.6276 Acc: 0.7679 Time elapsed: 204 sec.
# test Loss: 1.0637 Acc: 0.5749 Time elapsed: 211 sec.
#
# Epoch 6/29
# ----------
# train Loss: 0.4785 Acc: 0.8268 Time elapsed: 240 sec.
# test Loss: 1.0931 Acc: 0.5890 Time elapsed: 247 sec.
#
# Epoch 7/29
# ----------
# train Loss: 0.2978 Acc: 0.9140 Time elapsed: 275 sec.
# test Loss: 1.0633 Acc: 0.5989 Time elapsed: 282 sec.
#
# Epoch 8/29
# ----------
# train Loss: 0.2655 Acc: 0.9321 Time elapsed: 309 sec.
# test Loss: 1.0662 Acc: 0.6045 Time elapsed: 316 sec.
#
# Epoch 9/29
# ----------
# train Loss: 0.2441 Acc: 0.9435 Time elapsed: 344 sec.
# test Loss: 1.0739 Acc: 0.6101 Time elapsed: 351 sec.
#
# Epoch 10/29
# ----------
# train Loss: 0.2267 Acc: 0.9475 Time elapsed: 378 sec.
# test Loss: 1.0840 Acc: 0.6087 Time elapsed: 385 sec.
#
# Epoch 11/29
# ----------
# train Loss: 0.2115 Acc: 0.9530 Time elapsed: 414 sec.
# test Loss: 1.0955 Acc: 0.6059 Time elapsed: 421 sec.
#
# Epoch 12/29
# ----------
# train Loss: 0.1977 Acc: 0.9589 Time elapsed: 448 sec.
# test Loss: 1.1080 Acc: 0.6052 Time elapsed: 455 sec.
#
# Epoch 13/29
# ----------
# train Loss: 0.1849 Acc: 0.9628 Time elapsed: 483 sec.
# test Loss: 1.1214 Acc: 0.6017 Time elapsed: 490 sec.
#
# Epoch 14/29
# ----------
# train Loss: 0.1699 Acc: 0.9665 Time elapsed: 520 sec.
# test Loss: 1.1224 Acc: 0.6031 Time elapsed: 527 sec.
#
# Epoch 15/29
# ----------
# train Loss: 0.1684 Acc: 0.9675 Time elapsed: 554 sec.
# test Loss: 1.1240 Acc: 0.6038 Time elapsed: 561 sec.
#
# Epoch 16/29
# ----------
# train Loss: 0.1671 Acc: 0.9681 Time elapsed: 587 sec.
# test Loss: 1.1257 Acc: 0.6045 Time elapsed: 594 sec.
#
# Epoch 17/29
# ----------
# train Loss: 0.1658 Acc: 0.9681 Time elapsed: 623 sec.
# test Loss: 1.1274 Acc: 0.6073 Time elapsed: 631 sec.
#
# Epoch 18/29
# ----------
# train Loss: 0.1646 Acc: 0.9690 Time elapsed: 659 sec.
# test Loss: 1.1289 Acc: 0.6066 Time elapsed: 666 sec.
#
# Epoch 19/29
# ----------
# train Loss: 0.1634 Acc: 0.9699 Time elapsed: 694 sec.
# test Loss: 1.1305 Acc: 0.6066 Time elapsed: 700 sec.
#
# Epoch 20/29
# ----------
# train Loss: 0.1622 Acc: 0.9702 Time elapsed: 728 sec.
# test Loss: 1.1320 Acc: 0.6066 Time elapsed: 734 sec.
#
# Epoch 21/29
# ----------
# train Loss: 0.1607 Acc: 0.9696 Time elapsed: 762 sec.
# test Loss: 1.1321 Acc: 0.6059 Time elapsed: 769 sec.
#
# Epoch 22/29
# ----------
# train Loss: 0.1605 Acc: 0.9702 Time elapsed: 796 sec.
# test Loss: 1.1322 Acc: 0.6059 Time elapsed: 802 sec.
#
# Epoch 23/29
# ----------
# train Loss: 0.1604 Acc: 0.9705 Time elapsed: 831 sec.
# test Loss: 1.1323 Acc: 0.6059 Time elapsed: 837 sec.
#
# Epoch 24/29
# ----------
# train Loss: 0.1603 Acc: 0.9705 Time elapsed: 864 sec.
# test Loss: 1.1325 Acc: 0.6059 Time elapsed: 871 sec.
#
# Epoch 25/29
# ----------
# train Loss: 0.1601 Acc: 0.9705 Time elapsed: 898 sec.
# test Loss: 1.1326 Acc: 0.6059 Time elapsed: 905 sec.
#
# Epoch 26/29
# ----------
# train Loss: 0.1600 Acc: 0.9711 Time elapsed: 933 sec.
# test Loss: 1.1328 Acc: 0.6059 Time elapsed: 940 sec.
#
# Epoch 27/29
# ----------
# train Loss: 0.1599 Acc: 0.9711 Time elapsed: 967 sec.
# test Loss: 1.1330 Acc: 0.6059 Time elapsed: 974 sec.
#
# Epoch 28/29
# ----------
# train Loss: 0.1597 Acc: 0.9711 Time elapsed: 1001 sec.
# test Loss: 1.1330 Acc: 0.6059 Time elapsed: 1007 sec.
#
# Epoch 29/29
# ----------
# train Loss: 0.1597 Acc: 0.9711 Time elapsed: 1033 sec.
# test Loss: 1.1330 Acc: 0.6059 Time elapsed: 1040 sec.
#
# Training complete in 17m 20s
# Best val Acc: 0.610134
